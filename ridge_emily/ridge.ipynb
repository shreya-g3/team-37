# %%
# ridge regression - z-score normalised protein data

from ridge_regression import ridge_regression

results_df, per_protein_results_df = ridge_regression(
    rna_path="../../preprocessing/outputs/rna_hvg.h5ad",
    pro_path="../../preprocessing/outputs/protein_data_v2.h5ad",
    cv_split_path="../../preprocessing/outputs/cv_splits.json",
    alphas=[100, 1000, 5000, 10000, 50000],
    out_path="results")
# Out:
# Fold 1/5,
# best alpha=50000.00,
# mean Pearson r=0.288
# mean R2=0.086,
# mean RMSE=0.956
# Fold 2/5,
# best alpha=50000.00,
# mean Pearson r=0.317
# mean R2=0.104,
# mean RMSE=0.957
# Fold 3/5,
# best alpha=50000.00,
# mean Pearson r=0.279
# mean R2=0.080,
# mean RMSE=0.947
# Fold 4/5,
# best alpha=50000.00,
# mean Pearson r=0.310
# mean R2=0.099,
# mean RMSE=0.952
# Fold 5/5,
# best alpha=50000.00,
# mean Pearson r=0.256
# mean R2=0.068,
# mean RMSE=0.958
#
# Overall mean Pearson r across all proteins: 0.290 ± 0.0635
# Overall mean R² across all proteins: 0.088
# Overall mean RMSE across all proteins: 0.954
# Chosen alphas per fold: [50000, 50000, 50000, 50000, 50000]
#
# Top 10 best-predicted proteins:
# protein  mean_pearsonr  std_pearsonr  mean_r2  mean_rmse
#    MAP2       0.417603      0.022763 0.172981   0.908758
#     MPO       0.390804      0.054881 0.154319   0.918667
#    CD68       0.388125      0.116048 0.159663   0.911874
# ...
