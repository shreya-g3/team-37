# %%
# ridge regression

from ridge_regression import ridge_regression

results_df, per_protein_results_df = ridge_regression(
    rna_path="/Users/emilybeermann/Documents/IRBM/preprocessing/outputs/rna_hvg.h5ad",
    pro_path="/Users/emilybeermann/Documents/IRBM/preprocessing/outputs/protein_data.h5ad",
    cv_split_path="/Users/emilybeermann/Documents/IRBM/preprocessing/outputs/cv_splits.json",
    alphas=[100, 1000, 5000, 10000, 50000],
    out_path="results")
# Out:
# Fold 1/5,
# best alpha=50000.00,
# mean Pearson r=0.421
# mean R2=0.189,
# mean RMSE=0.435
# Fold 2/5,
# best alpha=50000.00,
# mean Pearson r=0.422
# mean R2=0.190,
# mean RMSE=0.436
# Fold 3/5,
# best alpha=50000.00,
# mean Pearson r=0.412
# mean R2=0.180,
# mean RMSE=0.435
# Fold 4/5,
# best alpha=50000.00,
# mean Pearson r=0.419
# mean R2=0.188,
# mean RMSE=0.436
# Fold 5/5,
# best alpha=50000.00,
# mean Pearson r=0.403
# mean R2=0.172,
# mean RMSE=0.434
#
# Overall mean Pearson r across all proteins: 0.416 ± 0.1069
# Overall mean R² across all proteins: 0.184
# Overall mean RMSE across all proteins: 0.435
# Chosen alphas per fold: [50000, 50000, 50000, 50000, 50000]
#
# Top 10 best-predicted proteins:
# protein  mean_pearsonr  std_pearsonr  mean_r2  mean_rmse
#     MPO       0.633115      0.019019 0.399638   0.238049
#    CD68       0.631498      0.014916 0.397467   0.374073
#   PD-L1       0.568808      0.016352 0.322553   0.171710
# ...
