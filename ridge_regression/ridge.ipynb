# %%
# ridge regression

from ridge_regression import ridge_regression

results_df, per_protein_results_df = ridge_regression(
    rna_path="../preprocessing/outputs/rna_hvg.h5ad",
    pro_path="../preprocessing/outputs/protein_data.h5ad",
    cv_split_path="../preprocessing/outputs/cv_splits.json",
    alphas=[100, 1000, 5000, 10000, 50000],
    out_path="results")
# Out:
# Fold 1/5,
# best alpha=50000.00,
# mean Pearson r=0.421
# Fold 2/5,
# best alpha=50000.00,
# mean Pearson r=0.422
# Fold 3/5,
# best alpha=50000.00,
# mean Pearson r=0.412
# Fold 4/5,
# best alpha=50000.00,
# mean Pearson r=0.419
# Fold 5/5,
# best alpha=50000.00,
# mean Pearson r=0.403
#
# Overall mean Pearson r across all proteins: 0.416 ± 0.1069
# Overall mean R² across all proteins: 0.184
# Chosen alphas per fold: [50000, 50000, 50000, 50000, 50000]
#
# Top 10 best-predicted proteins:
# protein  mean_pearsonr  std_pearsonr  mean_r2
#     MPO       0.633115      0.019019 0.399638
#    CD68       0.631498      0.014916 0.397467
#   PD-L1       0.568808      0.016352 0.322553
#    CD45       0.566294      0.014234 0.320504
#     TOX       0.561642      0.013107 0.314638
#    CD3e       0.550238      0.019979 0.302255
#     CD4       0.545276      0.014739 0.297255
#    FIBR       0.528667      0.011254 0.278761
#  HLA-DR       0.523196      0.009940 0.273463
#    MGMT       0.513864      0.015671 0.263712
