# %%
# ridge regression

from ridge_regression import ridge_regression

results_df, per_protein_results_df = ridge_regression(
    rna_path="../preprocessing/outputs/rna_hvg.h5ad",
    pro_path="../preprocessing/outputs/protein_data.h5ad",
    cv_split_path="../preprocessing/outputs/cv_splits.json",
    alphas=[100, 1000, 5000, 10000, 50000],
    out_path="results")
# Out:
# Fold 1/5,
# best alpha=50000.00,
# mean Pearson r=0.421
# mean R2=0.187,
# mean RMSE=0.437
# Fold 2/5,
# best alpha=50000.00,
# mean Pearson r=0.453
# mean R2=0.220,
# mean RMSE=0.446
# Fold 3/5,
# best alpha=50000.00,
# mean Pearson r=0.390
# mean R2=0.160,
# mean RMSE=0.420
# Fold 4/5,
# best alpha=50000.00,
# mean Pearson r=0.431
# mean R2=0.194,
# mean RMSE=0.447
# Fold 5/5,
# best alpha=50000.00,
# mean Pearson r=0.296
# mean R2=0.085,
# mean RMSE=0.432
#
# Overall mean Pearson r across all proteins: 0.398 ± 0.0999
# Overall mean R² across all proteins: 0.169
# Overall mean RMSE across all proteins: 0.436
# Chosen alphas per fold: [50000, 50000, 50000, 50000, 50000]
#
# Top 10 best-predicted proteins:
# protein  mean_pearsonr  std_pearsonr  mean_r2  mean_rmse
#    CD68       0.589520      0.138346 0.355820   0.376968
#     MPO       0.553273      0.199882 0.295774   0.239735
#    CD45       0.544277      0.093107 0.302604   0.327619
#     TOX       0.530199      0.075793 0.273828   0.361361
#     CD4       0.527189      0.081867 0.282660   0.259111
#   PD-L1       0.515692      0.157473 0.275268   0.173334
#  HLA-DR       0.509363      0.068314 0.261772   0.423961
#    CD3e       0.507975      0.128818 0.270901   0.209844
#    FIBR       0.498827      0.111307 0.255551   0.187574
#    MGMT       0.495763      0.079620 0.248017   0.379643
