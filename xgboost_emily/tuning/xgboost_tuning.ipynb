# %%
# install xgboost
#!pip install xgboost

# %% [markdown]
# # Tuning

# %%
# tuning
from xgboost_tuning import xgboost_tuning

best_params, search_results_df = xgboost_tuning(
        rna_path="../preprocessing/outputs/rna_hvg.h5ad",
        pro_path="../preprocessing/outputs/protein_data.h5ad",
        cv_split_path="../preprocessing/outputs/cv_splits.json",
        n_proteins_to_sample=8,  # how many proteins to tune on,
        n_iter=20,  # number of random param combos to try per protein
        random_state=42)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 # tuning
#       2 from xgboost_tuning import xgboost_tuning
# ----> 4 best_params, search_results_df = xgboost_tuning(
#       5         rna_path="../preprocessing/outputs/rna_hvg.h5ad",
#       6         pro_path="../preprocessing/outputs/protein_data.h5ad",
#       7         cv_split_path="../preprocessing/outputs/cv_splits.json",
#       8         n_proteins_to_sample=8,  # how many proteins to tune on,
#       9         n_iter=20,  # number of random param combos to try per protein
#      10         random_state=42)
#
# File ~/Documents/IRBM/xgboost_reg/xgboost_tuning.py:80, in xgboost_tuning(rna_path, pro_path, cv_split_path, n_proteins_to_sample, n_iter, random_state)
#      66 base_model = XGBRegressor(
#      67     tree_method="hist",
#      68     random_state=random_state,
# ...

# %% [markdown]
# # Tuning for XGBoost with truncated SVD

# %%
# tuning with protein_v2
from xgboost_tuning import xgboost_tuning_svd

best_params, search_results_df = xgboost_tuning_svd(
        rna_path="../../../xgboost_reg/preprocessing_outputs/rna_hvg.h5ad",
        pro_path="../../../xgboost_reg/preprocessing_outputs/protein_data_v3.h5ad",
        cv_split_path="../../../xgboost_reg/preprocessing_outputs/cv_splits_patches.json",
        n_components=50,
        A=None,
        svd_random_state=0,
        n_proteins_to_sample=8,
        n_iter=20,
        random_state=42)
# Out:
# SVD cumulative explained variance on tuning split: 0.165
# Protein Vimentin: best CV R2=0.042, params={'colsample_bytree': 0.7599443886861021, 'learning_rate': 0.01886647601058693, 'max_depth': 6, 'n_estimators': 563, 'subsample': 0.6931085361721216}
# Protein HLA-DR: best CV R2=0.118, params={'colsample_bytree': 0.9754210836063001, 'learning_rate': 0.010147965509792722, 'max_depth': 6, 'n_estimators': 376, 'subsample': 0.8469926038510867}
# Protein SYNA: best CV R2=0.294, params={'colsample_bytree': 0.7599443886861021, 'learning_rate': 0.01886647601058693, 'max_depth': 6, 'n_estimators': 563, 'subsample': 0.6931085361721216}
# Protein CD31: best CV R2=0.144, params={'colsample_bytree': 0.7599443886861021, 'learning_rate': 0.01886647601058693, 'max_depth': 6, 'n_estimators': 563, 'subsample': 0.6931085361721216}
# ...
